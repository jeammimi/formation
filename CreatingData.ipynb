# %%
# %matplotlib inline
from pylab import *
import numpy as np
import pandas as pd

# %%
#Generating data

# %%
X = np.random.rand(1000) * 10
X1 = np.random.rand(1000) * 100
Y = X*2+X1*0.1+np.random.rand(1000)*0.2

# %%
plot(X,Y,"o")
plot(X1,Y,"o")

# %%
pd.DataFrame({"LogP":Y,"MW":X1,"Polarity":X}).to_csv("example.csv",sep="\t",index=False)
